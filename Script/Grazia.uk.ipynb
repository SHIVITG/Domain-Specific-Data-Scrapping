# %%
from selenium import webdriver 
from selenium.webdriver.common.by import By 
from selenium.webdriver.support.ui import WebDriverWait, Select
from selenium.webdriver.support import expected_conditions as EC 
from selenium.webdriver.support.wait import WebDriverWait
from selenium.common.exceptions import TimeoutException
import time, re, csv, os
from selenium.webdriver.common.keys import Keys
import pandas as pd
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.support import expected_conditions
from selenium.webdriver.support.select import Select
from selenium.webdriver import ActionChains

# %%
driver = webdriver.Chrome('chromedriver_linux64/chromedriver')
driver.get("https://graziadaily.co.uk/fashion/")

# %%
def get_link():
    soup = BeautifulSoup(driver.page_source)
    for i in soup.findAll('div',{'class':'block-item'}):
        for items in i.findAll('div',{'class':'top'}):
            for j in items('a'):
                link1 = "https://graziadaily.co.uk" + j.get('href')
                print(link1)
                link.append(link1)

# %%
link = []
get_link()
# Out:
# https://graziadaily.co.uk/fashion/news/fashion-awards-rented-dresses-sustainability/
# https://graziadaily.co.uk/fashion/news/british-fashion-awards-winners/
# https://graziadaily.co.uk/fashion/shopping/bottega-veneta-fashion-week/
# https://graziadaily.co.uk/fashion/news/rihanna-launches-fenty-luxury-fashion-label-lvmh/
# https://graziadaily.co.uk/fashion/news/christopher-kane-more-joy-collection/
# https://graziadaily.co.uk/fashion/news/fashion-awards-puffer-dress-shailene-woodley-liya-kebede/
# https://graziadaily.co.uk/fashion/news/cate-blanchett-giorgio-armani/
# https://graziadaily.co.uk/fashion/news/armani-interview-fashion-awards/
# https://graziadaily.co.ukhttps://graziadaily.co.uk/fashion/news/palones-womenswear-clothes-sponsored/?utm_source=nativo
# https://graziadaily.co.uk/fashion/shopping/autumn-shopping-guide/
# https://graziadaily.co.uk/fashion/shopping/best-celebrity-jewellery-brands/
# https://graziadaily.co.uk/fashion/news/house-of-sunny-instagram-fashion/
# ...

# %%
for i in range(2,228):
    j = "https://graziadaily.co.uk/fashion/" + str(i) + "/"
    driver.get(j)
    get_link()
# Out:
# https://graziadaily.co.uk/fashion/shopping/black-friday-sales-sustainable-shopping/
# https://graziadaily.co.uk/fashion/news/normani-savage-fenty-success-victorias-secret-cancelled/
# https://graziadaily.co.uk/fashion/news/leather-shirt-trend/
# https://graziadaily.co.uk/fashion/news/francesca-hayward-bottega-veneta/
# https://graziadaily.co.uk/fashion/shopping/buy-swimwear-winter-sun-holiday/
# https://graziadaily.co.uk/fashion/shopping/marks-and-spencer-clothes/
# https://graziadaily.co.uk/fashion/news/fashion-activists-interviews/
# https://graziadaily.co.uk/fashion/news/wash-jumpers-without-calling-mum/
# https://graziadaily.co.uk/fashion/shopping/net-a-porter/
# https://graziadaily.co.uk/fashion/shopping/most-fashionable-gifts-christmas/
# https://graziadaily.co.uk/fashion/shopping/anthropologie-discount-code/
# https://graziadaily.co.uk/fashion/shopping/chain-belts/
# https://graziadaily.co.uk/fashion/news/shoes-wear-trousers-jeans/
# ...

# %%
len(link)
# Out:
# 6379

# %%
#f= open("grazia_uk.txt","w+")
count = 2872
for i in link[2872:]: 
    driver.get(i)
    soup = BeautifulSoup(driver.page_source)
    content = ""
    for j in soup.findAll('p'):
        content1= j.text
        content1 = content1.replace("\n","")
        content = content + content1
    print(content)
    print(count)
    f.write(content)
    count = count + 1
    print("............................")
# Out:
# Ad is loading...Summer calls for ice cream. All over your fine self. Here's some stuff to buy with ice creams on.£8, Little Papa @Ethical Market£36.62, Tory Burch£20, The Whitepepper @ ASOS£16, Fine Format @ NOTHS£32, Tallulah's Threads @ SilkFred£1.99, New Look£10, LalaLand£65, Lazy Oaf£24, ASOS£4, ASOS£80, Peter Jensen£6, Claire's£9, PaperchaseLike this? Then you might also be interested in:7 Of The Best Beach Bags To Buy And Then Use As Bags At The BeachWe Try On All The New Stuff In Urban Outfitters So You Don't Have To Flashback Friday To When Kim Kardashian Dressed Like You At The Year 11 DiscoFollow Jess on Twitter @Jess_CommonsThis article originally appeared on The Debrief.© 1962-2019 Bauer Media GroupBauer Media Group consists of: Bauer Consumer Media Ltd, Company number: 01176085, Bauer Radio Ltd, Company Number: 1394141Registered Office: Media House, Peterborough Business Park, Lynch Wood, Peterborough, PE2 6EA H Bauer Publishing,Company Number: LP003328Registered Office:
# ...

# %%
file = open("graziaUK.txt","w+")
with open("grazia_uk.txt", "w") as f:
    lines = ""
    for line in f:
        lines1 = line.replace("Ad is loading..."," ")
        lines.append(lines1)
    file.write(lines)
