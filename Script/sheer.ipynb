# %%
from selenium import webdriver 
from selenium.webdriver.common.by import By 
from selenium.webdriver.support.ui import WebDriverWait, Select
from selenium.webdriver.support import expected_conditions as EC 
from selenium.webdriver.support.wait import WebDriverWait
from selenium.common.exceptions import TimeoutException
import time, re, csv, os
from selenium.webdriver.common.keys import Keys
import pandas as pd
import requests
from bs4 import BeautifulSoup

from selenium import webdriver
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.support import expected_conditions
from selenium.webdriver.support.select import Select
from selenium.webdriver import ActionChains

# %%
driver = webdriver.Chrome('chromedriver_linux64/chromedriver')
driver.get("https://sheerluxe.com/style/fashion")

# %%
def get_link():
    soup = BeautifulSoup(driver.page_source)
    count = 1
    for i in soup.findAll('div',{'class':'view-content'}):
        for items in i('a'):
            link1 = "https://sheerluxe.com" + items.get('href')
            print(link1)
            link.append(link1)
            print(count)
            count = count + 1

# %%
link = []
get_link()
# Out:
# https://sheerluxe.com/2019/11/28/trend-report-90s
# 1
# https://sheerluxe.com/2019/11/28/favourite-picks-month
# 2
# https://sheerluxe.com/2019/11/28/24-payday-hits-buy-today
# 3
# https://sheerluxe.com/2019/11/28/30-stylish-pieces-boden
# 4
# https://sheerluxe.com/2019/11/28/21-fun-tights-wear-party-season
# 5
# https://sheerluxe.com/2019/11/27/new-it-bag-you-need
# 6
# https://sheerluxe.com/2019/11/27/debit-credit-try-laidback-party-look
# 7
# https://sheerluxe.com/2019/11/27/18-jewelled-knits-wear-party-season
# 8
# https://sheerluxe.com/2019/11/27/54-designer-pieces-shop-sale
# 9
# https://sheerluxe.com/2019/11/26/cool-designer-you-need-your-radar
# 10
# https://sheerluxe.com/2019/11/26/style-watch-outfits-week
# 11
# https://sheerluxe.com/2019/11/26/street-style-get-look
# 12
# https://sheerluxe.com/2019/11/26/18-faux-fur-coats-wear-winter
# 13
# https://sheerluxe.com/2019/11/26/12-cool-tracksuit-bottoms-wear-outdoors
# 14
# ...

# %%
#f= open("sheer.txt","w+")
count = 895
for i in link[895:]: 
    driver.get(i)
    soup = BeautifulSoup(driver.page_source)
    content = ""
    for j in soup.findAll('div',{'class':'field-intro'}):
        content1= j.text
        content = content +" "+ content1
        for j in soup.findAll('div',{'class','article-body'}):
            content2= j.text
            content = content +" "+ content2
    f.write(content)
    print(content)
    print(count)
    count = count + 1
    print("............................")
# Out:
#
#     Thought you’d never be caught dead in neon? Think again, as it’s about to be a big trend.
#
#
#
#
#
#
#
#
#
#
#
# No longer the reserve of 90s ravers and construction workers, neon is bright and is back in a big way in 2019. Consider it an extension of the 80s renaissance –  while metallics and mini skirts reigned supreme last year, now the fashion world is moving on to 90s neon, placing luminous ready-to-wear, accessories and even beauty at the top of the agenda.
# ...

# %%
with open('Sheer.txt', 'w+') as outfile:
    for line in infile:  
        line = line.replace("\n","")
        outfile.write(line)
